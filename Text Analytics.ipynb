# %%
import re
import os
import pandas as pd
import sklearn as sk
import numpy as np
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('maxent_ne_chunker')
nltk.download('words')
from nltk.tokenize import word_tokenize,sent_tokenize,RegexpTokenizer
from nltk import pos_tag
# Out:
# [nltk_data] Downloading package stopwords to /Users/Lusa1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/Lusa1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/Lusa1/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /Users/Lusa1/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/Lusa1/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /Users/Lusa1/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
content=[]
for filename in os.listdir('10'):
    if filename.endswith('.txt'):
        with open(os.path.join('10', filename),encoding="latin-1") as f:
             content.append(f.read())
    f.close()
    import operator
from functools import reduce
data=reduce(operator.concat, content)

# %%
content[29]
# Out:
# 'China exerts a massive amount influence on commodity markets.Â\xa0 It is said to account for 40 percent of base metal consumption and 23 percent of major agricultural commodities, according to an IMF working paper by Shaun Roache. It\'s an even bigger market for commodities than the U.S. And since a Chinese hard landing isn\'t completely off the table, it\'s worth considering how this would impact commodities. In a new note titled "What If China Lands Hard?" Societe Generale\'s head of commodities research, Michael Haigh writes, that a Chinese hard landing would both lower demand and hurt investor confidence, thereby delivering a double blow to the price of commodities. Societe Generale Gold In a hard landing scenario, some expect all commodities to plunge uniformly. Even gold prices could plunge because China is the second largest consumer of gold. However, gold\'s reaction is not so obvious. Haigh writes, that the impact on gold was the most difficult to forecast. Their model sugg
# ...

# %%
contentlist=[]
for filename in os.listdir('10'):
    if filename.endswith('.txt'):
        with open(os.path.join('10', filename),encoding="latin-1") as f:
             contentlist=f.readlines()
    f.close()

# %%
with open("2013-01-01.txt", encoding="latin-1") as datafile:
    data=datafile.read()
    print(data)
# Out:
# Earlier today we had a strong South Korean PMI report. The latest? Taiwan. It just saw a rise in December PMI from 47.4 to 50.6. From the report:
# With the House prepared to vote on the Senate fiscal cliff bill orchestrated by the White House and Senate Minority Leader Mitch McConnell, conservatives are railing against GOP House Speaker John Boehner for caving on the deal.Â  Here's the banner leading Drudge Report right now:Â  Drudge Report
# ...

# %%
with open("2013-01-01.txt", encoding="latin-1") as datafile:
    datalist=datafile.readlines()
    print(datalist)
# Out:
# ['Earlier today we had a strong South Korean PMI report. The latest? Taiwan. It just saw a rise in December PMI from 47.4 to 50.6. From the report: \n', "With the House prepared to vote on the Senate fiscal cliff bill orchestrated by the White House and Senate Minority Leader Mitch McConnell, conservatives are railing against GOP House Speaker John Boehner for caving on the deal.Â\xa0 Here's the banner leading Drudge Report right now:Â\xa0 Drudge Report\n", 'Good news for the global economy. South Korea -- whose heavy reliance on global trade -- is seen by some economists as the "canary in the coalmine" just came in with a strong PMI report. From the report: The HSBC South Korea Purchasing Managersâ\x80\x99 IndexTM (PMIÂ®) â\x80\x93 a composite indicator designed to provide a single-figure snapshot of the health of the manufacturing sector â\x80\x93 registered 50.1 in December. That was an improvement on Novemberâ\x80\x99s 48.2 and the highest reading since May. However, being barely
# ...

# %%
dfcomp = pd.read_csv('2013-01-01.txt', sep="/t", header=None,names=["a"])
print(dfcomp)
dfcomp['a']
# Out:
#                                                     a
# 0   Earlier today we had a strong South Korean PMI...
# 1   With the House prepared to vote on the Senate ...
# 2   Good news for the global economy. South Korea ...
# 3   UPDATE: As the Fiscal Cliff bill gets closer t...
# 4   Taxes increased for almost all Americans at mi...
# 5   The Senate has approved a tax deal to blunt so...
# 6   Just out from the CBO: A "score" of the Fiscal...
# 7   Here's the only thing that most Americans care...
# 8   Venture capitalist Fred Wilson, of Union Squar...
# 9   It's assumed that the House will pass the Fisc...
# 10  Most of the attention around the Fiscal Cliff ...
# 11  Assuming the House agrees to what the Senate v...
# 12  On January 1, just before 2 AM, the Senate ove...
# 13  Brendan Hoffman/Getty ImagesToday the Fiscal C...
# 14  WikipediaBurton Malkiel's classicReading a goo...
# 15  The Wall Street Journal has a big scare-story ...
# ...

# %%
tokens_text = word_tokenize(data)

# %%
type(tokens_text)
# Out:
# list

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent
sent = preprocess(data)
sent
# Out:
# [('Kentucky', 'NNP'),
#  ('Senator', 'NNP'),
#  ('Rand', 'NNP'),
#  ('Paul', 'NNP'),
#  ('(', '('),
#  ('R', 'NNP'),
#  (')', ')'),
#  ('is', 'VBZ'),
#  ('recommending', 'VBG'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('approach', 'NN'),
#  ('toward', 'IN'),
#  ('the', 'DT'),
#  ('debt', 'NN'),
#  ('ceiling', 'NN'),
#  ('standoff', 'NN'),
#  ('.', '.'),
#  ('Unlike', 'IN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('his', 'PRP$'),
#  ('fellow', 'JJ'),
#  ('Republicans', 'NNPS'),
#  (',', ','),
#  ('Paul', 'NNP'),
#  ('understands', 'VBZ'),
#  ('that', 'IN'),
#  ('forcing', 'VBG'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('to', 'TO'),
#  ('default', 'VB'),
#  ('by', 'IN'),
#  ('refusing', 'VBG'),
#  ('to', 'TO'),
#  ('raise', 'VB'),
#  ('the', 'DT'),
#  ('debt', 'NN'),
#  ('ceiling', 'NN'),
#  ('would', 'MD'),
#  ('make', 'VB'),
#  ('the', 'DT'),
#  ('Republicans', 'NNPS'),
#  ('look', 'VBP'),
#  ('reckless', 'JJ'),
#  ('and', 'CC'),
#  ('irresponsible', 'JJ'),
#  ('(', '('),
# ...

# %%
 pattern = 'CN: {<DT><NNP><NNP>*}'

# %%
pattern1 = 'PC: {<CD><NN>}'
cp1 = nltk.RegexpParser(pattern1)
cs1 = cp1.parse(sent)
print(cs1)
# Out:
# (S
#   Earlier/RB
#   today/NN
#   we/PRP
#   had/VBD
#   a/DT
#   strong/JJ
#   South/JJ
#   Korean/JJ
#   PMI/NNP
#   report/NN
#   ./.
#   The/DT
#   latest/JJS
#   ?/.
#   Taiwan/NNP
#   ./.
#   It/PRP
#   just/RB
#   saw/VBD
#   a/DT
#   rise/NN
#   in/IN
#   December/NNP
#   PMI/NNP
#   from/IN
#   47.4/CD
#   to/TO
#   50.6/CD
#   ./.
#   From/IN
#   the/DT
#   report/NN
#   :/:
#   With/IN
#   the/DT
#   House/NNP
#   prepared/VBD
#   to/TO
#   vote/VB
#   on/IN
#   the/DT
#   Senate/NNP
#   fiscal/JJ
#   cliff/NN
#   bill/NN
#   orchestrated/VBN
#   by/IN
#   the/DT
#   White/NNP
#   House/NNP
#   and/CC
#   Senate/NNP
#   Minority/NNP
#   Leader/NNP
#   Mitch/NNP
#   McConnell/NNP
#   ,/,
#   conservatives/NNS
#   are/VBP
#   railing/VBG
#   against/IN
#   GOP/NNP
#   House/NNP
#   Speaker/NNP
#   John/NNP
#   Boehner/NNP
#   for/IN
#   caving/VBG
#   on/IN
#   the/DT
#   deal.Â/NN
#   Here/RB
#   's/VBZ
#   the/DT
#   banner/NN
#   leading/VBG
#   Drudge/NNP
# ...

# %%
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Earlier/RB
#   today/NN
#   we/PRP
#   had/VBD
#   a/DT
#   strong/JJ
#   South/JJ
#   Korean/JJ
#   PMI/NNP
#   report/NN
#   ./.
#   The/DT
#   latest/JJS
#   ?/.
#   Taiwan/NNP
#   ./.
#   It/PRP
#   just/RB
#   saw/VBD
#   a/DT
#   rise/NN
#   in/IN
#   December/NNP
#   PMI/NNP
#   from/IN
#   47.4/CD
#   to/TO
#   50.6/CD
#   ./.
#   From/IN
#   the/DT
#   report/NN
#   :/:
#   With/IN
#   (CN the/DT House/NNP)
#   prepared/VBD
#   to/TO
#   vote/VB
#   on/IN
#   (CN the/DT Senate/NNP)
#   fiscal/JJ
#   cliff/NN
#   bill/NN
#   orchestrated/VBN
#   by/IN
#   (CN the/DT White/NNP House/NNP)
#   and/CC
#   Senate/NNP
#   Minority/NNP
#   Leader/NNP
#   Mitch/NNP
#   McConnell/NNP
#   ,/,
#   conservatives/NNS
#   are/VBP
#   railing/VBG
#   against/IN
#   GOP/NNP
#   House/NNP
#   Speaker/NNP
#   John/NNP
#   Boehner/NNP
#   for/IN
#   caving/VBG
#   on/IN
#   the/DT
#   deal.Â/NN
#   Here/RB
#   's/VBZ
#   the/DT
#   banner/NN
#   leading/VBG
#   Drudge/NNP
#   Report/NNP
# ...

# %%
from nltk.chunk import conlltags2tree, tree2conlltags, ne_chunk
from pprint import pprint
iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('Earlier', 'RB', 'O'),
#  ('today', 'NN', 'O'),
#  ('we', 'PRP', 'O'),
#  ('had', 'VBD', 'O'),
#  ('a', 'DT', 'O'),
#  ('strong', 'JJ', 'O'),
#  ('South', 'JJ', 'O'),
#  ('Korean', 'JJ', 'O'),
#  ('PMI', 'NNP', 'O'),
#  ('report', 'NN', 'O'),
#  ('.', '.', 'O'),
#  ('The', 'DT', 'O'),
#  ('latest', 'JJS', 'O'),
#  ('?', '.', 'O'),
#  ('Taiwan', 'NNP', 'O'),
#  ('.', '.', 'O'),
#  ('It', 'PRP', 'O'),
#  ('just', 'RB', 'O'),
#  ('saw', 'VBD', 'O'),
#  ('a', 'DT', 'O'),
#  ('rise', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('December', 'NNP', 'O'),
#  ('PMI', 'NNP', 'O'),
#  ('from', 'IN', 'O'),
#  ('47.4', 'CD', 'O'),
#  ('to', 'TO', 'O'),
#  ('50.6', 'CD', 'O'),
#  ('.', '.', 'O'),
#  ('From', 'IN', 'O'),
#  ('the', 'DT', 'O'),
#  ('report', 'NN', 'O'),
#  (':', ':', 'O'),
#  ('With', 'IN', 'O'),
#  ('the', 'DT', 'B-CN'),
#  ('House', 'NNP', 'I-CN'),
#  ('prepared', 'VBD', 'O'),
#  ('to', 'TO', 'O'),
#  ('vote', 'VB', 'O'),
#  ('on', 'IN', 'O'),
#  ('the', 'DT', 'B-CN'),
# ...

# %%
ne_tree = ne_chunk(pos_tag(word_tokenize(data)))
print(ne_tree)
# Out:
# (S
#   Earlier/RB
#   today/NN
#   we/PRP
#   had/VBD
#   a/DT
#   strong/JJ
#   (LOCATION South/JJ)
#   (LOCATION Korean/JJ PMI/NNP)
#   report/NN
#   ./.
#   The/DT
#   latest/JJS
#   ?/.
#   (GPE Taiwan/NNP)
#   ./.
#   It/PRP
#   just/RB
#   saw/VBD
#   a/DT
#   rise/NN
#   in/IN
#   December/NNP
#   PMI/NNP
#   from/IN
#   47.4/CD
#   to/TO
#   50.6/CD
#   ./.
#   From/IN
#   the/DT
#   report/NN
#   :/:
#   With/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   prepared/VBD
#   to/TO
#   vote/VB
#   on/IN
#   the/DT
#   (ORGANIZATION Senate/NNP)
#   fiscal/JJ
#   cliff/NN
#   bill/NN
#   orchestrated/VBN
#   by/IN
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   and/CC
#   (ORGANIZATION Senate/NNP)
#   Minority/NNP
#   Leader/NNP
#   (PERSON Mitch/NNP McConnell/NNP)
#   ,/,
#   conservatives/NNS
#   are/VBP
#   railing/VBG
#   against/IN
#   (ORGANIZATION GOP/NNP House/NNP)
#   Speaker/NNP
#   (PERSON John/NNP Boehner/NNP)
#   for/IN
#   caving/VBG
#   on/IN
#   the/DT
# ...

# %%
for sent in nltk.sent_tokenize(data):
    for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
        if hasattr(chunk, 'label'):
            print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# LOCATION South
# LOCATION Korean PMI
# GPE Taiwan
# ORGANIZATION House
# ORGANIZATION Senate
# FACILITY White House
# ORGANIZATION Senate
# PERSON Mitch McConnell
# ORGANIZATION GOP House
# PERSON John Boehner
# PERSON Drudge Report
# PERSON Drudge Report Good
# GPE South Korea
# ORGANIZATION PMI
# ORGANIZATION HSBC South Korea Purchasing
# ORGANIZATION PMI
# GPE New
# GPE Markit
# ORGANIZATION UPDATE
# ORGANIZATION Fiscal Cliff
# GPE Aussie
# GPE Hong Kong
# GPE Australia
# GPE Washington
# GPE American
# ORGANIZATION Senate
# GPE American
# ORGANIZATION House
# ORGANIZATION Representatives
# ORGANIZATION House
# ORGANIZATION Representatives
# ORGANIZATION Fiscal Cliff
# ORGANIZATION Senate
# ORGANIZATION Senate
# ORGANIZATION Senate
# GPE America
# ORGANIZATION SEE
# PERSON Great News
# ORGANIZATION For Romney
# ORGANIZATION Congress Just
# ORGANIZATION Senate
# ORGANIZATION Fiscal Cliff
# GPE America
# ORGANIZATION Congress
# PERSON Mitt Romney
# ORGANIZATION Republican
# ...

# %%
testpc=get_continuous_chunkslabel(data, "PERCENT")
testpc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-73e1eb058389> in <module>
# ----> 1 testpc=get_continuous_chunkslabel(data, "PERCENT")
#       2 testpc
#
# NameError: name 'get_continuous_chunkslabel' is not defined

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print([lemmatizer.lemmatize(token,"v") for token in word_tokenize(data)])
# Out:
# ['Earlier', 'today', 'we', 'have', 'a', 'strong', 'South', 'Korean', 'PMI', 'report', '.', 'The', 'latest', '?', 'Taiwan', '.', 'It', 'just', 'saw', 'a', 'rise', 'in', 'December', 'PMI', 'from', '47.4', 'to', '50.6', '.', 'From', 'the', 'report', ':', 'With', 'the', 'House', 'prepare', 'to', 'vote', 'on', 'the', 'Senate', 'fiscal', 'cliff', 'bill', 'orchestrate', 'by', 'the', 'White', 'House', 'and', 'Senate', 'Minority', 'Leader', 'Mitch', 'McConnell', ',', 'conservatives', 'be', 'rail', 'against', 'GOP', 'House', 'Speaker', 'John', 'Boehner', 'for', 'cave', 'on', 'the', 'deal.Â', 'Here', "'s", 'the', 'banner', 'lead', 'Drudge', 'Report', 'right', 'now', ':', 'Â', 'Drudge', 'Report', 'Good', 'news', 'for', 'the', 'global', 'economy', '.', 'South', 'Korea', '--', 'whose', 'heavy', 'reliance', 'on', 'global', 'trade', '--', 'be', 'see', 'by', 'some', 'economists', 'as', 'the', '``', 'canary', 'in', 'the', 'coalmine', "''", 'just', 'come', 'in', 'with', 'a', 'strong', 'PMI', 'report', 
# ...

# %%
from nltk.tree import Tree
def get_continuous_chunks(text):
        chunked = ne_chunk(pos_tag(word_tokenize(text)))
        continuous_chunk = []
        current_chunk = []
        for i in chunked:
                if type(i) == Tree:
                        current_chunk.append(" ".join([token for token, pos in i.leaves()]))
                elif current_chunk:
                        named_entity = " ".join(current_chunk)
                        if named_entity not in continuous_chunk:
                                continuous_chunk.append(named_entity)
                                current_chunk = []
                else:
                        continue
        return continuous_chunk

df = pd.DataFrame({'text':datalist})

a=df['text'].apply(lambda sent: get_continuous_chunks((sent)))

# %%
testcomp=pd.Series(a).sum()

# %%
testcomp1=get_continuous_chunks(data)
testcomp1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-611-80fe6d9b8a61> in <module>
# ----> 1 testcomp1=get_continuous_chunks(data)
#       2 testcomp1
#
# <ipython-input-609-010ae0d84789> in get_continuous_chunks(text)
#       1 from nltk.tree import Tree
#       2 def get_continuous_chunks(text):
# ----> 3         chunked = ne_chunk(pos_tag(word_tokenize(text)))
#       4         continuous_chunk = []
#       5         current_chunk = []
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/nltk/chunk/__init__.py in ne_chunk(tagged_tokens, binary)
#     184         chunker_pickle = _MULTICLASS_NE_CHUNKER
#     185     chunker = load(chunker_pickle)
# --> 186     return chunker.parse(tagged_tokens)
#     187
#     188
#
# ...

# %%
testcomp
# Out:
# ['China',
#  'IMF',
#  'Shaun Roache',
#  'U.S.',
#  'Chinese',
#  'China Hard',
#  'Societe Generale',
#  'Michael Haigh',
#  'Chinese Societe Generale Gold',
#  'China Haigh',
#  'Chinese PMIs',
#  'Patrick Legland',
#  'Societe Generale Chinese',
#  'Asian',
#  'Copper',
#  'Chinese U.S.',
#  'China PMI',
#  'Haigh',
#  'Chinese GDP',
#  'PMIs',
#  'Chinese Nickel',
#  'barrelÂ',
#  'Great Recession',
#  'SEC',
#  'Congress',
#  'Pitfalls',
#  'U.S. Investors',
#  'Chinese',
#  'YoY',
#  'Michael',
#  'YoY Trade',
#  'U.S.',
#  'EU',
#  'Japan',
#  'America',
#  'Chinese Bloomberg',
#  'U.S. Europe',
#  'Japan Hard',
#  'China',
#  'China Shanghai Composite',
#  'China Bloomberg',
#  'YoY YoY',
#  'China Bloomberg Michael McDonough',
#  'Michael McDonough',
#  'Twitter Â',
#  'Piece',
#  'Lu',
#  'SEE',
#  'SocGen',
#  'Gold',
#  'Hard Landing Scenario',
#  'Kristian',
#  'Images Oprah Winfrey',
#  'Lance Armstrong',
#  'Oprah',
#  'Armstrong',
#  'Armstrong New York Times',
# ...

# %%
len(dfcomp[:])
f1=testcomp
compf1= pd.DataFrame(list(zip(testcomp, f1)), 
               columns =['Comp', 'f1'])
compf1.set_index("Comp",inplace = True)
compf1.loc["Taiwan", 'f1'] = 1
compf1.loc["Taiwan"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-599-649abcd0e263> in <module>
#       4                columns =['Comp', 'f1'])
#       5 compf1.set_index("Comp",inplace = True)
# ----> 6 compf1.loc["Taiwan", 'f1'] = 1
#       7 compf1.loc["Taiwan"]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     203             key = com.apply_if_callable(key, self.obj)
#     204         indexer = self._get_setitem_indexer(key)
# --> 205         self._setitem_with_indexer(indexer, value)
#     206
#     207     def _validate_key(self, key, axis: int):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     389                     index = self.obj._get_axis(i)
# ...

# %% [markdown]
# # CEO name

# %%
#feature for CEO in a line
f1=testcomp
ceof1= pd.DataFrame(list(zip(testcomp, f1)), 
               columns =['Comp', 'f1'])
ceof1.set_index("Comp",inplace = True)
for i in testcomp:
    for line in datalist:
        if i in line:
            if "CEO" in line:
                ceof1.loc[i, 'f1'] = 1

            else:
                ceof1.loc[i, 'f1'] = 0
        else:
            ceof1.loc[i, 'f1'] = 0
            continue
ceof1
# Out:
#                    f1
# Comp
# South Korean PMI    0
# Taiwan              0
# House               0
# Senate              0
# White House         0
# ...                ..
# Business            0
# MBA                 0
# Ed John Mauldin     0
# American Taxpayer   0
# Fiscal Cliff        0
#
# [253 rows x 1 columns]

# %%
#feature for CEO next to the candidate
f2=f1
ceof2= ceof1
ceof2['f2'] = f2
for i in testcomp:
    for n in range(len(tokens_text)-2):
        if i == tokens_text[n]:
            if "CEO"==tokens_text[n-1]:
                ceof2.loc[i, 'f2'] = 1
            else:
                ceof2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]:
            if "CEO"==tokens_text[n-1]:
                    ceof2.loc[i, 'f2'] = 1
            else:
                ceof2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]:
            if "CEO"==tokens_text[n-1]:
                    ceof2.loc[i, 'f2'] = 1
            else:
                ceof2.loc[i, 'f2'] = 0

            
        else:
            
            continue
ceof2.loc[ceof2['f1'] == 0, 'f2'] = 0
ceof2
# Out:
#                    f1  f2
# Comp
# South Korean PMI    0   0
# Taiwan              0   0
# House               0   0
# Senate              0   0
# White House         0   0
# ...                ..  ..
# Business            0   0
# MBA                 0   0
# Ed John Mauldin     0   0
# American Taxpayer   0   0
# Fiscal Cliff        0   0
#
# [253 rows x 2 columns]

# %%
for i in testcomp:
    for n in range(len(tokens_text)-1):
        if i == tokens_text[n]+' '+tokens_text[n+1]:
            if "CEO"==tokens_text[n-1]:
                ceof2.loc[i, 'f2'] = 1
            else:
                ceof2.loc[i, 'f2'] = 0
       

            
        else:
            
            continue

ceof2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-222-f773f4112588> in <module>
#       1 for i in testcomp:
#       2     for n in range(len(tokens_text)-1):
# ----> 3         if i == tokens_text[n]+' '+tokens_text[n+1]:
#       4             if "CEO"==tokens_text[n-1]:
#       5                 ceof2.loc[i, 'f2'] = 1
#
# KeyboardInterrupt:

# %%
for i in testcomp:
    for n in range(len(tokens_text)-2):
        if i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]:
            if "CEO"==tokens_text[n-1]:
                ceof2.loc[i, 'f2'] = 1
            else:
                ceof2.loc[i, 'f2'] = 0
       

            
        else:
            
            continue
ceof2.loc[ceof2['f1'] == 0, 'f2'] = 0
ceof2

# %%
labelceo=pd.read_csv('ceo1.csv',encoding="latin-1",header=None)
type(labelceo)
labelceo= labelceo[0].values.tolist()
labelceo
# Out:
# ['Tom Horton',
#  'Patti Hart',
#  'Jamie Dimon',
#  'Steve Cohen',
#  'Tim Cook',
#  'Steve Jobs',
#  'Daniel Doctoroff',
#  'Laura Lang',
#  'Andrew Mason',
#  'Jeffrey Gundlach',
#  'Tim Armstrong',
#  'Elon Musk',
#  'Maurice Taylor',
#  'Mark Benioff',
#  'Thomas Jones',
#  'Don Thompson',
#  'Ron Johnson',
#  'Michael Eisner',
#  'Mark Zuckerberg',
#  'Apu Gupta',
#  'Sergio Marchionne',
#  'John Thain',
#  'John Bilbrey',
#  'Myron Ullman',
#  'Ross Levinsohn',
#  'Dick Fuld',
#  'Alan Mulally',
#  'Jeff Bezos',
#  'Tim Clark',
#  'Brady Dougan',
#  'Stephen Hester',
#  'Avishai Abrahami',
#  'Graham Weston',
#  'Joe Magnacca',
#  'Antony Jenkins',
#  'Steve Ballmer',
#  'Brad Katsuyama',
#  'John Wren',
#  'Jonathan Bush',
#  'Mario Gabelli',
#  'Jayshree Ullal',
#  'Robert Thomas',
#  'David Pyott',
#  'Lorenzo Grabau',
#  'Lloyd Blankfein',
#  'Genaro Garcia',
#  'Indra Nooyi',
#  'Javier Romero',
#  'Mark Fields',
#  'James Mitarotonda',
#  'Jonathan Lu',
# ...

# %%
ceof2.loc[ceof2['f1'] == 0, 'f2'] = 0

# %%
y=f1
ceof2['y'] = y
for n in ceof2.index:
    if n not in labelceo:
        ceof2.loc[n, 'y'] = 0
    else:
        ceof2.loc[n, 'y'] = 1
        continue
ceof2
# Out:
#                    f1  f2  y
# Comp
# South Korean PMI    0   0  0
# Taiwan              0   0  0
# House               0   0  0
# Senate              0   0  0
# White House         0   0  0
# ...                ..  .. ..
# Business            0   0  0
# MBA                 0   0  0
# Ed John Mauldin     0   0  0
# American Taxpayer   0   0  0
# Fiscal Cliff        0   0  0
#
# [253 rows x 3 columns]

# %%
ceof2[ceof2['y']==1]
# Out:
#                 f1  f2  y
# Comp
# Jimmy Cayne      0   0  1
# Warren Buffett   0   0  1
# Bill Gross       0   0  1

# %%
X3 = ceof2.iloc[:, [0, 1]].values
y3 = ceof2.iloc[:, 2].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size = 0.25, random_state = 0)

# %%
testper=get_continuous_chunkslabel(data, "PERSON")
testper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-710c695a2118> in <module>
# ----> 1 testper=get_continuous_chunkslabel(data, "PERSON")
#       2 testper
#
# NameError: name 'get_continuous_chunkslabel' is not defined

# %%
df = pd.DataFrame(data=testper)
df.index=testper
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-708fa807f2d0> in <module>
# ----> 1 df = pd.DataFrame(data=testper)
#       2 df.index=testper
#
# NameError: name 'testper' is not defined

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()
logisticRegr.fit(X3_train, y3_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Returns a NumPy Array
# Predict for One Observation (image)
logisticRegr.predict(X3_test[0].reshape(1,-1))
predictions = logisticRegr.predict(X3_test)

# %%
# Use score method to get accuracy of model
score = logisticRegr.score(X3_test, y3_test)
print(score)
# Out:
# 0.984375

# %%
ceof2['Prob']=list(logisticRegr.predict_proba(X3)[:,1])
ceof2
# Out:
#                    f1  f2  y      Prob
# Comp
# South Korean PMI    0   0  0  0.010582
# Taiwan              0   0  0  0.010582
# House               0   0  0  0.010582
# Senate              0   0  0  0.010582
# White House         0   0  0  0.010582
# ...                ..  .. ..       ...
# Business            0   0  0  0.010582
# MBA                 0   0  0  0.010582
# Ed John Mauldin     0   0  0  0.010582
# American Taxpayer   0   0  0  0.010582
# Fiscal Cliff        0   0  0  0.010582
#
# [253 rows x 4 columns]

# %%
ceof2[ceof2['Prob']>0.5]

# %%
import matplotlib.pyplot as plt
#import seaborn as sns
from sklearn import metrics

# %%
cm = metrics.confusion_matrix(y_test, predictions)
print(cm)
# Out:
# [[63  0]
#  [ 1  0]]

# %% [markdown]
# # Company name

# %%
labelcomp=pd.read_csv('companies.csv',header=None)
labelcomp=labelcomp[0].values.tolist()
labelcomp
# Out:
# ['Abaxis Inc',
#  'ACA Financial',
#  'Alibaba Group Holding Ltd',
#  'American Bell Telephone Co',
#  'American Express Co',
#  'American International Group Inc',
#  'Apple Inc',
#  'Audience Inc',
#  'Avis Budget Group',
#  'Bakrie Group',
#  'Belarus Potash Co',
#  'Berkshire Hathaway Inc',
#  'Bespoke Investment Group',
#  'Best Buy Co Inc',
#  'Blackstone Group',
#  'Boeing Co',
#  'Boston Consulting Group',
#  'Campbell Soup Co',
#  'Canadian Mortgages Inc',
#  'Citigroup Inc',
#  'Commidea Ltd',
#  'Commodity Weather Group LLC',
#  'Dell Inc',
#  'Digital Media Group',
#  'Diversified Machine Inc',
#  'Enterprise Networking Group',
#  'Everbright Securities Ltd',
#  'Facebook Inc',
#  'Fox Residential Group',
#  'Fujitsu Ltd',
#  'GE',
#  'Geely Automobile Holdings Ltd',
#  'General Motors Co',
#  'Gerontology Research Group',
#  'Goldman Sachs Group Inc',
#  'Google Inc',
#  'Herbalife Ltd',
#  'Hewlett Packard Co',
#  'Hillshire Brands Co',
#  'Hostess Brands Inc',
# ...

# %%
#feature for COMPANY name in a line
f1=testcomp
compf1= pd.DataFrame(list(zip(testcomp, f1)), 
               columns =['Comp', 'f1'])
compf1.set_index("Comp",inplace = True)
for i in testcomp:
    for line in datalist:
        if i in line:
            if "company" in line:
                compf1.loc[i, 'f1'] = 1

            else:
                compf1.loc[i, 'f1'] = 0
        else:
            compf1.loc[i, 'f1'] = 0
            continue
compf1
# Out:
#                    f1
# Comp
# South Korean PMI    0
# Taiwan              0
# House               0
# Senate              0
# White House         0
# ...                ..
# Business            0
# MBA                 0
# Ed John Mauldin     0
# American Taxpayer   0
# Fiscal Cliff        0
#
# [253 rows x 1 columns]

# %%
#feature for CEO next to the candidate
f2=f1
compf2= compf1
compf2['f2'] = f2
for i in testcomp:
    for n in range(len(tokens_text)-4):
        if i == tokens_text[n]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+1]:
                compf2.loc[i, 'f2'] = 1
            else:
                compf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+2]:
                    compf2.loc[i, 'f2'] = 1
            else:
                compf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+3]:
                    compf2.loc[i, 'f2'] = 1
            else:
                compf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]+' '+tokens_text[n+3]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+4]:
                    compf2.loc[i, 'f2'] = 1
            else:
                compf2.loc[i, 'f2'] = 0

            
        else:
            
            continue
compf2.loc[compf2['f1'] == 0, 'f2'] = 0
compf2
# Out:
#                    f1  f2
# Comp
# South Korean PMI    0   0
# Taiwan              0   0
# House               0   0
# Senate              0   0
# White House         0   0
# ...                ..  ..
# Business            0   0
# MBA                 0   0
# Ed John Mauldin     0   0
# American Taxpayer   0   0
# Fiscal Cliff        0   0
#
# [253 rows x 2 columns]

# %%
y=f1
compf2['y'] = y
for n in compf2.index:
    if n not in labelcomp:
        compf2.loc[n, 'y'] = 0
    else:
        compf2.loc[n, 'y'] = 1
        continue
compf2
# Out:
#                    f1  f2  y
# Comp
# South Korean PMI    0   0  0
# Taiwan              0   0  0
# House               0   0  0
# Senate              0   0  0
# White House         0   0  0
# ...                ..  .. ..
# Business            0   0  0
# MBA                 0   0  0
# Ed John Mauldin     0   0  0
# American Taxpayer   0   0  0
# Fiscal Cliff        0   0  0
#
# [253 rows x 3 columns]

# %%
compf2[compf2['y']==1]
# Out:
#                           f1  f2  y
# Comp
# Union Square Ventures      0   0  1
# Citi                       0   0  1
# Facebook                   0   0  1
# Morgan Stanley             0   0  1
# Apple                      0   0  1
# Business Insider           0   0  1
# Nasdaq                     0   0  1
# Frontline                  0   0  1
# PIMCO                      0   0  1
# Research Affiliates        0   0  1
# Altegris                   0   0  1
# Nicola Wealth Management   0   0  1

# %%
X1 = compf2.iloc[:, [0, 1]].values
y1 = compf2.iloc[:, 2].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()
logisticRegr.fit(X1_train, y1_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Returns a NumPy Array
# Predict for One Observation (image)
logisticRegr.predict(X1_test[0].reshape(1,-1))
predictions = logisticRegr.predict(X1_test)

# %%
# Use score method to get accuracy of model
score = logisticRegr.score(X1_test, y1_test)
print(score)
# Out:
# 0.984375

# %%
list1=list(logisticRegr.predict_proba(X1)[:,1])
compf2['Prob']=list1
compf2
# Out:
#                    f1  f2  y      Prob
# Comp
# South Korean PMI    0   0  0  0.058201
# Taiwan              0   0  0  0.058201
# House               0   0  0  0.058201
# Senate              0   0  0  0.058201
# White House         0   0  0  0.058201
# ...                ..  .. ..       ...
# Business            0   0  0  0.058201
# MBA                 0   0  0  0.058201
# Ed John Mauldin     0   0  0  0.058201
# American Taxpayer   0   0  0  0.058201
# Fiscal Cliff        0   0  0  0.058201
#
# [253 rows x 4 columns]

# %%
compf2[compf2['Prob']>0.7]

# %%
type(compf2)
# Out:
# list

# %% [markdown]
# # percentages

# %%
import spacy

# Load English tokenizer, tagger, parser, NER and word vectors
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc = nlp(data)

# %%
# Analyze syntax
percent = []
for token in doc.ents:
     if token.label_ == 'PERCENT':
            percent1.append(token)
            
percent=[str(item) for item in percent1]
percent
# Out:
# ['1.2%',
#  '47%',
#  '39.6%',
#  '47%',
#  '47%',
#  '4.2%',
#  'the 47%',
#  '35%',
#  '39.6%',
#  '4.2% to 6.2%',
#  '15% to 20%',
#  'an additional 3.8%',
#  '23.8%',
#  '39.6%',
#  '15%',
#  '18.8%',
#  '80-90%',
#  '40%',
#  '10%',
#  '3%',
#  'close to 3%',
#  '2%',
#  '1.7%',
#  '2%',
#  'only 1.5%',
#  'about only 1.4%',
#  '1.9 percent',
#  '99 percent',
#  'below 0.5 percent',
#  '1%',
#  '1%',
#  '3%',
#  '2%',
#  '1%',
#  '0%',
#  '3%',
#  'more than 3%',
#  '3%',
#  'close to 3%',
#  '3%',
#  '2%',
#  'about 9.3%',
#  '9%',
#  '1%',
#  '1%',
#  '26%',
#  '9%',
#  '3%',
#  '2%',
#  '1%',
#  '1%',
#  '1.5%',
#  '1%',
#  '0.4%',
#  '3%',
#  '8%',
#  '7-8%',
#  '1.2%',
#  '47%',
#  '39.6%',
#  '47%',
#  '47%',
#  '4.2%',
#  'the 47%',
#  '35%',
#  '39.6%',
#  '4.2% to 6.2%',
#  '15% to 20%',
#  'an additional 3.8%',
#  '23.8%',
#  '39.6%',
#  '15%',
#  '18.8%',
#  '80-90%',
#  '40%',
#  '10%',
#  '3%',
#  'close to 3%',
#  '2%',
#  '1.7%',
#  '2%',
#  'only 1.5%',
# ...

# %%
percent=percent+percent1
test=pd.DataFrame(data=percent)

# %%
len(percent)
# Out:
# 27685

# %%
    test.to_csv('CEO1.csv',encoding='utf-8')

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)

# %%
#feature for percent in a line
f1=percent
perf1= pd.DataFrame(list(zip(percent, f1)), 
               columns =['Per', 'f1'])
perf1.set_index("Per",inplace = True)
for i in percent:
    for n in datalist:
        if i in n:
            if  "percentage" in line:
                perf1.loc[i, 'f1'] = 1

            else:
                perf1.loc[i, 'f1'] = 0
        else:
            perf1.loc[i, 'f1'] = 0
            continue
perf1
# Out:
#        f1
# Per
# 1.2%    0
# 47%     0
# 39.6%   0
# 47%     0
# 47%     0
# ...    ..
# 1%      0
# 0.4%    0
# 3%      0
# 8%      0
# 7-8%    0
#
# [114 rows x 1 columns]

# %%
for i in range(len(f1)+1):
    f2= [0] * i
len(f1)==len(f2)
# Out:
# True

# %%
#feature for percent next to the candidate
for i in range(len(f1)+1):
    f2= [0] * i
perf2= perf1
perf2['f2'] = f2
for i in percent:
    for n in range(len(tokens_text)-4):
        if i == tokens_text[n]+' '+tokens_text[n+1]:
            if "by"or"to"or"from"or"at"==tokens_text[n-1]:
                perf2.loc[i, 'f2'] = 1
            else:
                perf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]+' '+tokens_text[n+3]+' '+tokens_text[n+4]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+2]:
                    perf2.loc[i, 'f2'] = 1
            else:
                perf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+3]:
                    perf2.loc[i, 'f2'] = 1
            else:
                perf2.loc[i, 'f2'] = 0
        elif i == tokens_text[n]+' '+tokens_text[n+1]+' '+tokens_text[n+2]+' '+tokens_text[n+3]:
            if "Inc"or"Co"or"Group"or"Ltd"==tokens_text[n+4]:
                   perf2.loc[i, 'f2'] = 1
            else:
                perf2.loc[i, 'f2'] = 0

        

            
        else:
           
            
            continue

perf2
# Out:
#        f1  f2
# Per
# 1.2%    0   0
# 47%     0   0
# 39.6%   0   0
# 47%     0   0
# 47%     0   0
# ...    ..  ..
# 1%      0   0
# 0.4%    0   0
# 3%      0   0
# 8%      0   0
# 7-8%    0   0
#
# [114 rows x 2 columns]

# %%
labelper=pd.read_csv('percentage.csv',encoding="latin-1",header=None)
labelper=labelper[0].values.tolist()
labelper

# %%
y=f1
perf2['y'] = y
for n in perf2.index:
    if n not in labelper:
        perf2.loc[n, 'y'] = 0
    else:
        perf2.loc[n, 'y'] = 1
        continue

# %%
X2 = perf2.iloc[:, [0, 1]].values
y2 = perf2.iloc[:, 2].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LogisticRegression
# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()
logisticRegr.fit(X2_train, y2_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Returns a NumPy Array
# Predict for One Observation (image)
logisticRegr.predict(X2_test[0].reshape(1,-1))
predictions = logisticRegr.predict(X2_test)

# %%
# Use score method to get accuracy of model
score = logisticRegr.score(X2_test, y2_test)
print(score)
# Out:
# 0.4827586206896552

# %%
perf2['Prob']=list(logisticRegr.predict_proba(X2)[:,1])
perf2
# Out:
#        f1  f2  y     Prob
# Per
# 1.2%    0   0  0  0.63645
# 47%     0   0  1  0.63645
# 39.6%   0   0  0  0.63645
# 47%     0   0  1  0.63645
# 47%     0   0  1  0.63645
# ...    ..  .. ..      ...
# 1%      0   0  1  0.63645
# 0.4%    0   0  0  0.63645
# 3%      0   0  1  0.63645
# 8%      0   0  1  0.63645
# 7-8%    0   0  0  0.63645
#
# [114 rows x 4 columns]

# %%
perf2[perf2['Prob']>0.5]
# Out:
#        f1  f2  y     Prob
# Per
# 1.2%    0   0  0  0.63645
# 47%     0   0  1  0.63645
# 39.6%   0   0  0  0.63645
# 47%     0   0  1  0.63645
# 47%     0   0  1  0.63645
# ...    ..  .. ..      ...
# 1%      0   0  1  0.63645
# 0.4%    0   0  0  0.63645
# 3%      0   0  1  0.63645
# 8%      0   0  1  0.63645
# 7-8%    0   0  0  0.63645
#
# [114 rows x 4 columns]
